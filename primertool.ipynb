# %%
import primertool as pt

# Please enter your own kuerzel here. It will appear on the generated order table
pt.config.KUERZEL = 'XX'

# %% [markdown]
# # Create a primer for a given mutation
# requires a mutation in hgvs format (only NM numbers) and a genome version (hg19 or hg38)

# %%
x = pt.PrimerMutation('NM_003165.6:c.1702G>A', 'hg38')
x.create_primer()
# Out:
# INFO:root:Valid Sequence Identifier in NM_003165.6:c.1702G>A
# INFO:root:An 'mRNA' sequence was used with the 'c.' coordinate system. Make use of a genomic reference sequence if the experiment performed involved measured DNA.
# INFO:root:Retrieving gene information from RefSeq database
# INFO:root:Mutation in exon, running PrimerExon
# INFO:root:Retrieving gene information from RefSeq database
# INFO:root:number of exons 20
# INFO:root:This exon number exists in this gene.
# INFO:root:No primers were found yet, increasing sequence size
# INFO:root:Primers generated. 1 primers found.
# INFO:root:Writing output to /home/simon/Documents/work/primertool/primertool/output/STXBP1_exon18_primer.txt
#         Datum Auftraggeber             Primer zur Bestellung Gen/Fragment  \
# 0  22.01.2024           XX  STXBP1-E18F;CACTAGATGCCGTGAGTGCA       STXBP1
# 1  22.01.2024           XX  STXBP1-E18R;AGCGTGGAATGGAGTTGAGG       STXBP1
#
#   Transkript  Schmelztemperatur   bp
# ...
